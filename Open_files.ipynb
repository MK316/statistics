# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/statistics/blob/main/Open_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: CSV file
#
#
# ---

# %% [markdown]
# ### [1] Loading csv file to Colab from your computer.
# On the left panel, Files > upload a file

# %% [markdown]
# ### See screen capture to find out where is Files panel.

# %% [markdown]
# ![Screen Shot 2022-04-23 at 11.01.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Show file content
# - Using pandas package

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['engpro22mid.csv']))
df.head()

# %% [markdown]
# ### [2] Upload csv file using Finder
# - Choose files (files from your computer)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d0ef856d-6e3f-4295-a285-cdab579cb39a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0ef856d-6e3f-4295-a285-cdab579cb39a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving engpro22mid.csv to engpro22mid.csv

# %% [markdown]
# - type(uploaded): [dict]

# %%
# Read csv file uploaded as pandas dataframe
df1 = pd.read_csv(io.BytesIO(uploaded['engpro22mid.csv']))
# Out:
#    id       score
# 0   1  137.500000
# 1   2  131.166667
# 2   3  125.833333
# 3   4   99.333333
# 4   5   67.833333

# %%
# Read the first 5 rows of df1
df1.head()
# Out:
#    id       score
# 0   1  137.500000
# 1   2  131.166667
# 2   3  125.833333
# 3   4   99.333333
# 4   5   67.833333

# %% [markdown]
# ### [3] csv file from [Github]('https://github.com/')
# - Using [pandas] package

# %%
url = 'https://raw.githubusercontent.com/MK316/Learning01/main/engpro22mid.csv'
df3 = pd.read_csv(url)

# %%
df3.head()
# Out:
#    id       score
# 0   1  137.500000
# 1   2  131.166667
# 2   3  125.833333
# 3   4   99.333333
# 4   5   67.833333

# %% [markdown]
# ---
#
#
# # Part II: text file (string data)
# - [handling string data in Python]('https://realpython.com/python-strings/')

# %% [markdown]
# ## [1] Copy and paste

# %%
# text = "Paste your text here."
text1 = "A Dove saw an Ant fall into a brook. The Ant struggled in vain to reach the bank, and in pity, the Dove dropped a blade of straw close beside it. Clinging to the straw like a shipwrecked sailor to a broken spar, the Ant floated safely to shore. Soon after, the Ant saw a man getting ready to kill the Dove with a stone. But just as he cast the stone, the Ant stung him in the heel, so that the pain made him miss his aim, and the startled Dove flew to safety in a distant wood."

# %%
# text line break using \ in the following format.
text2 = """A Dove saw an Ant fall into a brook. The Ant struggled in vain to reach the bank, \
and in pity, the Dove dropped a blade of straw close beside it. \
Clinging to the straw like a shipwrecked sailor to a broken spar, \
the Ant floated safely to shore.
Soon after, the Ant saw a man getting ready to kill the Dove with a stone. \
But just as he cast the stone, the Ant stung him in the heel, \
so that the pain made him miss his aim, and the startled Dove flew to safety in a distant wood."""

# %%
# text1 and text2 have the same length.
print(len(text1)); print(len(text2))
# Out:
# 477
# 477

# %% [markdown]
# ## [2] File upload using Choose Files

# %%
from google.colab import files
uploaded = files.upload()
uploaded = str(uploaded)
# Out:
#      <input type="file" id="files-87ac4831-b477-4be1-bfed-6bf82d7724c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87ac4831-b477-4be1-bfed-6bf82d7724c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DoveAndAnt.txt to DoveAndAnt.txt

# %%
file = open("DoveAndAnt.txt", "r")
text3 = file.read().replace("\n", " ")
file.close()

# %%
print(len(text3))
text3
# Out:
# 479
# 'A Dove saw an Ant fall into a brook. The Ant struggled in vain to reach the bank, and in pity, the Dove dropped a blade of straw close beside it. Clinging to the straw like a shipwrecked sailor to a broken spar, the Ant floated safely to shore. Soon after, the Ant saw a man getting ready to kill the Dove with a stone. But just as he cast the stone, the Ant stung him in the heel, so that the pain made him miss his aim, and the startled Dove flew to safety in a distant wood.  '

# %% [markdown]
# ## [3] File from Github
# Notes:
# - Get a link of the file located in Github file.
# - 'raw' link is required. (Select the file and press 'raw' on the menu.

# %%
import base64
import requests

url = "https://raw.githubusercontent.com/MK316/codes/main/DoveAndAnt.txt"
file = requests.get(url)
text4 = file.text
print(text4)
# Out:
# A Dove saw an Ant fall into a brook. The Ant struggled in vain to reach the bank, and in pity, the Dove dropped a blade of straw close beside it. Clinging to the straw like a shipwrecked sailor to a broken spar, the Ant floated safely to shore. Soon after, the Ant saw a man getting ready to kill the Dove with a stone. But just as he cast the stone, the Ant stung him in the heel, so that the pain made him miss his aim, and the startled Dove flew to safety in a distant wood.

# %%
# Getting 20 strings from the text4
text4[:20]
# Out:
# 'A Dove saw an Ant fa'
